# %%
persona = {"nombre":"jose", "edad": 25, "cuidad":"monteria"}
print (persona)

persona["profesion"] = "futbolista"
print(persona)

del persona ["cuidad"]
print(persona)

noHijos = input("Ingrese numeros de hijos ")
print("Numero de hijos", noHijos)

print("Este es mi Bucle For :")
for i in range(2, 6):
    print(i)

print("Este es mi Bucle con un solo argumento :")
for i in range(5):
    print(i)

print("Este es mi Bucle con paso :")
for i in range(0, 10, 2):
    print(i)
# Out:
# {'nombre': 'jose', 'edad': 25, 'cuidad': 'monteria'}
# {'nombre': 'jose', 'edad': 25, 'cuidad': 'monteria', 'profesion': 'futbolista'}
# {'nombre': 'jose', 'edad': 25, 'profesion': 'futbolista'}
# Ingrese numeros de hijos 3
# Numero de hijos 3
# Este es mi Bucle For :
# 2
# 3
# 4
# 5
# Este es mi Bucle con un solo argumento :
# 0
# 1
# 2
# 3
# 4
# Este es mi Bucle con paso :
# 0
# 2
# 4
# 6
# 8
