# %%
# Definimos 4 variables
a = 5
b = 10
c = 7
d = 3

# Hacemos la suma
resultado = a + b + c + d

# Mostramos el resultado
print("La suma de las 4 variables es:", resultado)
# Out:
# La suma de las 4 variables es: 25

# %%
# Definimos 4 variables
a = 20
b = 5
c = 3
d = 2

# Hacemos la resta
resultado = a - b - c - d

# Mostramos el resultado
print("La resta de las 4 variables es:", resultado)
# Out:
# La resta de las 4 variables es: 10

# %%
# Definimos 4 variables
a = 2
b = 3
c = 4
d = 5

# Hacemos la multiplicación
resultado = a * b * c * d

# Mostramos el resultado
print("La multiplicación de las 4 variables es:", resultado)
# Out:
# La multiplicación de las 4 variables es: 120

# %%
# Definimos 4 variables
a = 100
b = 5
c = 2
d = 2

# Hacemos la división
resultado = a / b / c / d

# Mostramos el resultado
print("La división de las 4 variables es:", resultado)
# Out:
# La división de las 4 variables es: 5.0

# %%
# Definimos 2 variables
base = 5
exponente = 3

# Hacemos la potenciación
resultado = base ** exponente

# Mostramos el resultado
print(base, "elevado a", exponente, "es:", resultado)
# Out:
# 5 elevado a 3 es: 125

# %%
# Definimos dos variables
a = 10
b = 5

# Usamos el operador AND
resultado = (a > 5) and (b < 10)

# Mostramos el resultado
print("El resultado de (a > 5) and (b < 10) es:", resultado)
# Out:
# El resultado de (a > 5) and (b < 10) es: True

# %%
# Definimos dos variables
a = 10
b = 5

# Usamos el operador OR
resultado = (a < 5) or (b < 10)

# Mostramos el resultado
print("El resultado de (a < 5) or (b < 10) es:", resultado)
# Out:
# El resultado de (a < 5) or (b < 10) es: True

# %%
# Definimos dos variables
a = 10
b = 5

# Usamos el operador NOT
resultado = not (a == b)

# Mostramos el resultado
print("El resultado de not (a == b) es:", resultado)
# Out:
# El resultado de not (a == b) es: True

# %%
# Definimos dos variables
a = 4
b = 10

# Usamos el operador <
resultado = a < b

# Mostramos el resultado
print("¿a es menor que b?:", resultado)
# Out:
# ¿a es menor que b?: True

# %%
# Definimos dos variables
a = 15
b = 8

# Usamos el operador >
resultado = a > b

# Mostramos el resultado
print("¿a es mayor que b?:", resultado)
# Out:
# ¿a es mayor que b?: True

# %%
# Definimos dos variables
a = 7
b = 7

# Usamos el operador ==
resultado = a == b

# Mostramos el resultado
print("¿a es igual a b?:", resultado)
# Out:
# ¿a es igual a b?: True

# %%
# Definimos dos variables
a = 10
b = 7

# Usamos el operador !=
resultado = a != b

# Mostramos el resultado
print("¿a es diferente de b?:", resultado)
# Out:
# ¿a es diferente de b?: True
